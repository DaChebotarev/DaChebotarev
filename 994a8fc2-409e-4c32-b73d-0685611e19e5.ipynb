# %% [markdown]
# <div class="alert alert-info">
# Привет, Мария! Меня зовут Светлана Чих и я буду проверять твой проект. Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе. Предлагаю общаться на «ты». Но если это не удобно - дай знать, и мы перейдем на «вы».
#
# <div class="alert alert-success">
# <b>👍 Успех:</b> Зелёным цветом отмечены удачные и элегантные решения, на которые можно опираться в будущих проектах.
# </div>
# <div class="alert alert-warning">
# <b>🤔 Рекомендация:</b> Жёлтым цветом выделено то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас (однако это не обязательно).
# </div>
# <div class="alert alert-danger">
# <b>😔 Необходимо исправить:</b> Красным цветом выделены комментарии, без исправления которых, я не смогу принять проект :(
# </div>
# <div class="alert alert-info">
# <b>👂 Совет:</b> Какие-то дополнительные материалы
# </div>
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом.
# Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# <div class="alert alert-info"> <b>🎓 Комментарий студента:</b> Например, вот так.</div>
# Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии. Всё это поможет выполнить повторную проверку твоего проекта быстрее.
#  </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-warning">
# <b>🤔 Рекомендация:</b> Описательная часть очень важна в проекте, в ней нужно выделять цель работы, влючать в нее план работы. Написание плана работы облегчит выполнения проекта и позволит четко выстроить его структуру и не пропустить важные шаги
# </div>

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data= pd.read_csv('/datasets/real_estate_data.csv', sep = '\t')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
data.hist(figsize= (15,20))
# Out:
# array([[<AxesSubplot:title={'center':'total_images'}>,
#         <AxesSubplot:title={'center':'last_price'}>,
#         <AxesSubplot:title={'center':'total_area'}>,
#         <AxesSubplot:title={'center':'rooms'}>],
#        [<AxesSubplot:title={'center':'ceiling_height'}>,
#         <AxesSubplot:title={'center':'floors_total'}>,
#         <AxesSubplot:title={'center':'living_area'}>,
#         <AxesSubplot:title={'center':'floor'}>],
#        [<AxesSubplot:title={'center':'kitchen_area'}>,
#         <AxesSubplot:title={'center':'balcony'}>,
#         <AxesSubplot:title={'center':'airports_nearest'}>,
#         <AxesSubplot:title={'center':'cityCenters_nearest'}>],
#        [<AxesSubplot:title={'center':'parks_around3000'}>,
#         <AxesSubplot:title={'center':'parks_nearest'}>,
#         <AxesSubplot:title={'center':'ponds_around3000'}>,
#         <AxesSubplot:title={'center':'ponds_nearest'}>],
#        [<AxesSubplot:title={'center':'days_exposition'}>, <AxesSubplot:>,
# ...

# %% [markdown]
# **Вывод**
# замечено:
# -всего 22 категории
# -есть много несоответствия между категориями и типами данных в них
# -в некоторых категориях есть пропуски значений, которые необходимо заполнить

# %% [markdown]
# <div class="alert alert-warning">
# <b>🤔 Рекомендация:</b> Импорты и считывание датасета лучше делать в разных ячейках, выводы пишеться после произведенных действий, сейчас у тебя вывод написан в пункте, где данные не просматривались
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> Первичное исследование датасета проводится в этом пункте, поэтому код нужно перенести сюда. Нужно построить общую гистограмму для всех столбцов таблицы</s>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>
#     исправила
#  </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %% [markdown]
# ### Предобработка данных

# %%
#выведем на экран долю пропусков по каждому столбцу в процентах 
pd.DataFrame(round(data.isna().mean()*100,1))
# Out:
#                          0
# total_images           0.0
# last_price             0.0
# total_area             0.0
# first_day_exposition   0.0
# rooms                  0.0
# ceiling_height        38.8
# floors_total           0.4
# living_area            8.0
# floor                  0.0
# is_apartment          88.3
# studio                 0.0
# open_plan              0.0
# kitchen_area           9.6
# balcony               48.6
# locality_name          0.2
# airports_nearest      23.4
# cityCenters_nearest   23.3
# parks_around3000      23.3
# parks_nearest         65.9
# ponds_around3000      23.3
# ponds_nearest         61.6
# days_exposition       13.4

# %%
#Убираем строки с пропусками floors_total, их количество очень мало, удаление не отразится на статистике
data = data.loc[data['floors_total'].isna()==False]

# %% [markdown]
# <div class="alert alert-warning">
# <b>🤔 Рекомендация:</b> Все комментарии должны быть в Markdown ячейках
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно! Менее 1% пропусков можно удалить
# </div>

# %%
#наглядно рассмотрим корреляцию параметров друг от друга 
corr_matrix = data.corr()
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_5a2f0_row0_col0,#T_5a2f0_row1_col1,#T_5a2f0_row2_col2,#T_5a2f0_row3_col3,#T_5a2f0_row4_col4,#T_5a2f0_row5_col5,#T_5a2f0_row6_col6,#T_5a2f0_row7_col7,#T_5a2f0_row8_col8,#T_5a2f0_row9_col9,#T_5a2f0_row10_col10,#T_5a2f0_row11_col11,#T_5a2f0_row12_col12,#T_5a2f0_row13_col13,#T_5a2f0_row14_col14,#T_5a2f0_row15_col15,#T_5a2f0_row16_col16,#T_5a2f0_row17_col17,#T_5a2f0_row18_col18{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_5a2f0_row0_col1,#T_5a2f0_row4_col6,#T_5a2f0_row4_col14,#T_5a2f0_row9_col16{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_5a2f0_row0_col2,#T_5a2f0_row5_col15,#T_5a2f0_row5_col17{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_5a2f0_row0_col3,#T_5a2f0_row12_col17{
#             background-color:  #93b5fe;
#             color:  #000000;
#         }#T_5a2f0_row0_col4,#T_5a2f0_row8_col4{
# ...

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> Данные еще не предобработаны, смотреть корреляцию рано, сначала приведем данные в порядок и только потом бедем исследовать</s>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>
# Эта матрица построена не для исследовательского анализа, а для того, чтобы выполнить предобработку данных, чтобы было наглядно видно что с чем коррелируется и мы могли заполнить пропущенные значения. В данном случае это инструмент для предобработки данных, поэтому и сделала её вначале
#  </div>

# %%
#заменим пропуски в столбце living_area на медианное значение в зависимотси от количества комнат 
#for i in data['rooms'].unique():
    #data.loc[(data['living_area'].isna())& (data['rooms']==i), 'living_area'] = \
    #data.loc[data['rooms']==i, 'living_area'].median()

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> Почему эти пропуски могли возникнуть? У нас для всех квартир есть данные по общей площади, может быть есть варианты использовать ее при заполнении пропусков? При заполнении в твоем варианте у всех квартир жилая площадь полкчиласт меньше общей? </s>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>🎓Ниже сделала более подробную градацию и на её основании заполнила жилую площадь, надеюсь при такой градации жилая площадь не должна получиться больше общей.

# %%
#посмотрим каким образом лучше разделить на группы квартиры исходя из их общей площали
data.plot(y ='total_area', kind= 'hist', bins=100, grid=True, range=(0,600), figsize=(3,5))
plt.title("total_area")
plt.xlabel("total_area")
plt.ylabel("count")
data['total_area'].describe()
# Out:
# count    23613.000000
# mean        60.340678
# std         35.648988
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.800000
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# **Вывод:**
# Исходя из данной гистограммы квартиры можно разделить на следующие группы:
# XXXS - площадь до 10 кв.м
# XXS - площадь от 10 до 20 кв.м
# XS - площадь от 20 до 30 кв.м
# S - площадь от 30 до 40 кв.м
# M - площадь от 40 до 50 кв.м
# L - площадь от 50 до 60 кв.м
# XL - площадь от 60 до 70 кв.м
# XXL - площадь от 70 до 80 кв.м
# XXXL - площадь от 80 до 90 кв.м
# XXXXL - площадь 90 кв.м

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> У визуализаций дожен быть заголовок и подписи осей, после того, как мы что-то смотрим должен быть вывод, ты здесь проверял как лучше разделить квартиры, но не написала, что в итоге решила</s>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>
#     исправила
#  </div>

# %%
#заменим пропуски в столбце kitchen_area 
#разделим все объекты датафрейма на 4 группы в зависимости от общей площади - total_area
def categorize_total_area(area):
    try:
        if 0 <= area <= 10:
            return 'XXXS'
        elif 10 <= area <= 20:
            return 'XXS'
        elif 20 <= area <= 30:
            return 'XS'
        elif 30 <= area <= 40:
            return 'S'
        elif 40 <= area <= 50:
            return 'M'
        elif 50 <= area <= 60:
            return 'L'
        elif 60 <= area <= 70:
            return 'XL'
        elif 70 <= area <= 80:
            return 'XXL'
        elif 80 <= area <= 90:
            return 'XXXL'
        elif area >= 90:
            return 'XXXXL'
    except:
        pass

# %%
#добавим столбец с размером квартир в датафрейм
data['total_area_size'] = data['total_area'].apply(categorize_total_area)

# %%
#заменим пропуски в столбце living_area на медианное значение в зависимотси от ранее определенного размера квартиры  
for i in data['total_area_size'].unique():
    data.loc[(data['living_area'].isna())& (data['total_area_size']==i), 'living_area'] = \
    data.loc[data['total_area_size']==i, 'living_area'].median()

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> У всех квартир есть кухни? Действительно ли при таком делении кухни одинаковые? 55-60 кв.м это может быть "двушка" в новостройке с огромной кухней или старая "трешка" с очень маленькой кухней. Насколько нам важно заполнить все пропуски и насколько достоверно мы можем это сделать?</s>
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>🤔 Рекомендация:</b> Мы можем найти соотношение жилой площади и общей (можно предварительно разделив квартиры по группам и для каждой группы найти свой коэффициент). и используя этот кэффициент вычислить жилую площадь из бщей для всех кваритр
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>🎓убрала заполнение этих пропусков.

# %%
#заменим пропуски в balcony на 0 и изменим тип данных на int
data['balcony'].value_counts()
data['balcony'] = data['balcony'].fillna(0)
data['balcony'] = data['balcony'].astype('int')

# %%
#посмотрим параметр ceiling_height, видим что есть необоснованно большие значения но пока оставим их как есть,
#медиана от среднего отличается не сильно из-за этих выбросов во всей выборке
data['ceiling_height'].describe()
# Out:
# count    14495.000000
# mean         2.771495
# std          1.261445
# min          1.000000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# поскольку параметр высоты потолков ни с чсем не кореллируется, но имеет очень большой процент пропусков, оставим эти пропуски как есть, но постараемся максимально привести данные в порядок, предположим что необоснованно большие значения в столбце ceiling_height могли возникнуть из-за ошибки при записи, посколько эти данные вносятся вручную,
# возмодно заполняющий не поставил запятую или поставил не в том месте, напишем функцию которая отредактирует такие показатели

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> Что получилось после применения такой функции? В новых домах и домах-"сталинках" потолки 3,2-4м, что бльше 3 и  будет разделено на 10. Может быть потомлок 0,4 м? Или 1 м (а именно столько мы получим, если изначально указано 10м)?</s>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>🎓убрала эту функцию, заменила её на другое решение ниже

# %%
data.update(data[(data['ceiling_height'] >= 20) & (data['ceiling_height'] <= 40)]['ceiling_height']/10)
data['ceiling_height'].unique()
# Out:
# array([  2.7 ,    nan,   3.03,   2.5 ,   2.67,   2.56,   3.05,   2.75,
#          2.6 ,   2.9 ,   2.8 ,   2.55,   3.  ,   2.65,   3.2 ,   2.61,
#          3.25,   3.45,   2.77,   2.85,   2.64,   2.57,   4.15,   3.5 ,
#          3.3 ,   2.71,   4.  ,   2.47,   2.73,   2.84,   3.1 ,   2.34,
#          3.4 ,   3.06,   2.72,   2.54,   2.51,   2.78,   2.76,   2.58,
#          3.7 ,   2.52,   5.2 ,   2.87,   2.66,   2.59,   2.  ,   2.45,
#          3.6 ,   2.92,   3.11,   3.13,   3.8 ,   3.15,   3.55,   3.16,
#          3.62,   3.12,   2.53,   2.74,   2.96,   2.46,   5.3 ,   5.  ,
#          2.79,   2.95,   4.06,   2.94,   3.82,   3.54,   3.53,   2.83,
#          4.7 ,   2.4 ,   3.38,   3.01,   5.6 ,   3.65,   3.9 ,   3.18,
#          3.35,   2.3 ,   3.57,   2.48,   2.62,   2.82,   3.98,   2.63,
#          3.83,   3.52,   3.95,   3.75,   2.88,   3.67,   3.87,   3.66,
#          3.85,   3.86,   4.19,   3.24,   4.8 ,   4.5 ,   4.2 ,   3.36,
# ...

# %% [markdown]
# <div class="alert alert-info"> <b>
#     исправила
#  </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно! Так получилось более правдоподобно
# </div>

# %%
#изменим тип некоторых данных в датафрейме
#переведем столбец с датой в формат даты без времени, т.к. время не указано
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format = '%Y-%m-%d')
data['days_exposition'] = data['days_exposition'].fillna(0).astype('int')

# %%
#Убираем строки с пропусками locality_name, их количество очень мало, удаление не отразится на статистике
data = data.loc[data['locality_name'].isna()==False]

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно! Их тоже мало, но логично было бы в самом начале удалить пропуски во всех столбцах, где их мало (посчитав сколько всего данных удалено)
# </div>

# %%
pd.DataFrame(round(data.isna().mean()*100,1))
# Out:
#                          0
# total_images           0.0
# last_price             0.0
# total_area             0.0
# first_day_exposition   0.0
# rooms                  0.0
# ceiling_height        38.5
# floors_total           0.0
# living_area            0.0
# floor                  0.0
# is_apartment          88.3
# studio                 0.0
# open_plan              0.0
# kitchen_area           9.4
# balcony                0.0
# locality_name          0.0
# airports_nearest      23.4
# cityCenters_nearest   23.3
# parks_around3000      23.3
# parks_nearest         65.9
# ponds_around3000      23.3
# ponds_nearest         61.7
# days_exposition        0.0
# total_area_size        0.0

# %% [markdown]
# **Вывод:**
# Некоторые пропуски в столбцах решено было оставить, а именно:
# - ceiling_height -
# - is_apartment -
# - airports_nearest -
# - cityCenters_nearest -
# - parks_around3000 -
# - ponds_nearest -
# потому что эти пропуски не коррелируются ни с одним показателем, поэтому выстроить алгоритм их заполнения невозможно.
# Пропуски в столбце is_apartment могли появится по причине невнимательности заполняющего, возможно этот столбец появился в анкете не сразу, возможно пропуск значит, что квартира не является апортаментами, но точно утверждать мы этого не могжем, поэтому было принято решение оставить как есть.
# параметр высоты потолков ни с чсем не кореллируется, но имеет очень большой процент пропусков, оставим эти пропуски как есть, в реальности было бы хорошо запросить год постройки дома, в таком случае, можно было бы заполнить пустые значения медианными по группе.
# Пропуски в географических параметрах (- airports_nearest -
# - cityCenters_nearest -
# - parks_around3000 -
# - ponds_nearest - )
# совсем не зависят ни от каких других, и как мы знаем, они заполняются в анкете автоматически, а не человеком, заменять их на нулевые значения нельзя, поэтому также оставим как есть.

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> Обработаны не все пропуски, если какие то данные решено оставить как есть, то их все равно нужно исследовать, предположить причину появления пропусков и обосновать свое решение оставить их или заполнить</s>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>🎓исправила

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %%
#посмотрим какие названия встречаются в столбце с названиями локаций
unique_locality_name = data['locality_name'].unique()

# %%
#выведем все уникальные названия в столбец одно за другим, и посмотрим сколько каких количественно 
pd.options.display.max_rows = 400
#display(data['locality_name'].value_counts())
#устраним неявные дубликаты
data['locality_name'] = (data['locality_name'].str.replace('ё', 'е'))
data['locality_name'] = data['locality_name'].replace(['поселок при железнодорожной станции ', 
                'поселок городского типа ','село ', 'деревня ', 'городской поселок ',
                'коттеджный поселок ', 'садоводческое некоммерческое товарищество ', 
                'садовое товарищество ', 'поселок '], '', regex=True)
data['locality_name'].unique()
# Out:
# /tmp/ipykernel_48/1895296800.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['locality_name'] = (data['locality_name'].str.replace('ё', 'е'))
# /tmp/ipykernel_48/1895296800.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['locality_name'] = data['locality_name'].replace(['поселок при железнодорожной станции ',
# array(['Санкт-Петербург', 'Шушары', 'Янино-1', 'Парголово', 'Мурино',
#        'Ломоносов', 'Сертолово', 'Петергоф', 'Пушкин', 'Кудрово',
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <b>🤔 Рекомендация:</b> Стоит отсортировать названия по алфавиту, что бы можно было легко заметить, если какие то еще варианты написания ты не учла
# </div>

# %% [markdown]
# мы провели предаброботку данных в которой удалили малочисленные пропуски в столбцах с парметрами floors_total и locality_name, пропуски в этих столбах занимали менее одного процента, поэтому их удаление не отразилось на общей статистике.
# Так же мы устранили пропуски в столбцах  living_area и kitchen_area. Посмотрев на матрице корреляции мы решили что, в  первом случае мы сгруппируем  квартиры по количеству комнат и заменим пропуски медианным значением в каждой категории (1, 2, 3 комнатные квартиры и тд)
# Во втором случае, чтобы корректно заменить пропуски, мы разделили все квартиры на группы в зависимости от общей пощади и далее заменили пропуски медианными занчениями, по группам.
# В столбце с данными о высотке потолков было слишком много пропусков(38,8%), но к сожалению по матрице корреляции не нашлось зависимости, чтобы модно было объективно эти пропуски замнить, поэтому пропуски оставили как есть, но постарались выжать максимум информации из того, что было дано, поэтому предположили что потолки выше 3х м это выбросы, которые появилмсь в результате ошибки заполнения анкеты, потому все потолки выше 3х метров мы разделили на 10. Таким образом удалось спасти 0,3% данных.
# В столбце с названием города было очень много неявных дубликатов, которые мы так же устранили.

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %%
#добавим столбец с ценой за 1 квадратный метр
data['price_per_square_meter'] = data['last_price']/data['total_area']
data['price_per_square_meter'] = data['price_per_square_meter'].astype('int')
#добавим столбец номера дня недели
data['weekday_exposition'] = data['first_day_exposition'].dt.weekday
#добавим столбец месяца
data['month_exposition'] = data['first_day_exposition'].dt.month
#добавим столбец года
data['year_exposition'] = data['first_day_exposition'].dt.year
# Out:
# /tmp/ipykernel_48/3081417170.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['price_per_square_meter'] = data['last_price']/data['total_area']
# /tmp/ipykernel_48/3081417170.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['price_per_square_meter'] = data['price_per_square_meter'].astype('int')
# /tmp/ipykernel_48/3081417170.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
#создадим функцию для определния категории этажа
def floor_category(row):
    floors_total = row['floors_total']
    floor = row['floor']
    if floor == 1:
        return 'первый'
    elif floor == floors_total:
        return 'последний'
    elif 1 < floor < floors_total:
        return 'другой'
    
#категоризуем этажи с помощью функции  
data['floor_category'] = data.apply(floor_category, axis = 1)
# Out:
# /tmp/ipykernel_48/2753518604.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['floor_category'] = data.apply(floor_category, axis = 1)

# %%
#добавим столбец с расстоянием до центра в километрах
data['Center_nearest_in_km'] = data['cityCenters_nearest'] / 1000
data['Center_nearest_in_km'] = data['Center_nearest_in_km'].round(0)
# Out:
# /tmp/ipykernel_48/3819437286.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Center_nearest_in_km'] = data['cityCenters_nearest'] / 1000
# /tmp/ipykernel_48/3819437286.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Center_nearest_in_km'] = data['Center_nearest_in_km'].round(0)

# %% [markdown]
# <div class="alert alert-warning">
# <b>🤔 Рекомендация:</b> Новые столбцы добавлены, но после любых преобразований нужно смотреть на данные, точно ли все получилось как нужно?
# </div>

# %%
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00           2019-03-07      3
# 1                 7   3350000.0       40.40           2018-12-04      1
# 2                10   5196000.0       56.00           2015-08-20      2
# 3                 0  64900000.0      159.00           2015-07-24      3
# 4                 2  10000000.0      100.00           2018-06-19      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81           2017-03-21      3
# 23695            14   3100000.0       59.00           2018-01-15      3
# 23696            18   2500000.0       56.70           2018-02-11      2
# 23697            13  11475000.0       76.75           2017-03-28      2
# 23698             4   1350000.0       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> Нужно отдельно проверить даные на редкие и выбвающиеся значения, при необходимости отфильтровать их. В таких исследованиях хорошо применять комбиначию гистограмм распределения и боксплотов, так же смотреть перцентили. Все выбивающиеся значения нужно изучить и понять могут ли они существовать в реальности и только после этого принимать решение о каких-то действиях с ними.</s>
# </div>

# %%
data_1 = data

# %%
#изучим общую площадь
data.plot(y = 'total_area', kind = 'hist', bins = 100, grid=True, figsize = (5,3), range = (0,900))
data['total_area'].describe()
# Out:
# count    23565.000000
# mean        60.322824
# std         35.657060
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.700000
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# из гистограммы видно, большая часть квартир находится в диапазоне площади от 30 до 105 кв.м;

# %%
data.boxplot('total_area', vert=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_97/972747600.py in <module>
# ----> 1 data.boxplot('total_area', vert=False)
#
# NameError: name 'data' is not defined

# %% [markdown]
# из боксплота видно, медиана проходи через значение 52 кв.м, квартиры с площадью более 101 кв.м считаются выбросами,
# но на парктике, мы не может утвержадть, что это нереальные значения

# %%
data_1= data.loc[data['total_area']< 200]
data_1.boxplot('total_area', vert=False)
# Out:
# <AxesSubplot:>

# %%
data_1['total_area'].describe()
# Out:
# count    23335.000000
# mean        58.126632
# std         26.449663
# min         12.000000
# 25%         40.000000
# 50%         51.700000
# 75%         68.760000
# max        199.200000
# Name: total_area, dtype: float64

# %%
print(((data['total_area'].count()-data_1['total_area'].count())/data['total_area'].count()*100))
# Out:
# 0.976023764056864

# %% [markdown]
# Из гистограммы размаха видно, что есть совсем небольшое количество выпадов, из них не все являются нереальными
# значениями, квартиры общей площадью 200 кв.м не являются нереальными. Квартир с общей площадью более 200 кв.м в
# датасете менее 1%, на общую статистику они очень слабо влияют поэтому удалять их не будем, так как мы не можем
# наверняка утверждать, что это ошибочные значения и таких квартир нет.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> После исследования каждого признака должен быть комментарий поясняющих что в данных (в Markdown ячейке), это нужно исправить по всему разделу</s>
# </div>

# %%
#изучим цену квартиры
#data['last_price'] = data['last_price']/1000000
pd.options.display.float_format = '{:20,.2f}'.format
data.plot(y = 'last_price', kind = 'hist', bins = 300, grid=True, range = (0,50000000),figsize = (3,5))
data['last_price'].describe()
# Out:
# count              23,565.00
# mean            6,540,058.26
# std            10,910,934.72
# min                12,190.00
# 25%             3,400,000.00
# 50%             4,646,000.00
# 75%             6,790,000.00
# max           763,000,000.00
# Name: last_price, dtype: float64

# %% [markdown]
# из гистограммы видно, большая часть квартир находится в ценовом диапазоне  от 5 до 10 млн;

# %%
data.boxplot('last_price', vert=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# боксплот показывает, медиана проходи через значение 4 650 000, а квартиры стоимостью более 9 млн. являются выбросами, но в реальности квартиру могут стоить довольно много, поэтому, неизвестно есть ли лимит у цены, однако боксплот на показал выбросы в меньшую сторону, хотя очевидно, что квартира не может стоить 12 тыс. руб.;

# %%
data= data.loc[data['last_price']> 500000]

# %% [markdown]
#  мы не можем утверждать, что квартиры стоимостью более 50 млн это нереальные значения, выбивающиеся значения в большую сторону в данном случае удалять не будем, а вот квартиры стоимостью менее 500 тыс. уберем.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %%
#изучим число комнат
data.plot(y = 'rooms', kind = 'hist', bins = 30, grid=True, figsize = (5,3))
data['rooms'].describe()
# Out:
# count              23,547.00
# mean                    2.07
# std                     1.08
# min                     0.00
# 25%                     1.00
# 50%                     2.00
# 75%                     3.00
# max                    19.00
# Name: rooms, dtype: float64

# %%
data.boxplot('rooms', vert=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# на гистограмме видно, что болишинство квартир с количеством комнат от 1 до 5, максимальное значение исходя из дискрайб 19, возможно такая квартира действительно существует, природа этого выброса непонятна, также на графиках видно, что есть определенное количество квартир с количеством комнат равным 0, скорее всего это квартиры студии и количество изолированных комнат в них действительно равно 0, поэтому в этом столбце все данные оставим, как есть.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %%
#изучим высоту потолков
data.plot(y = 'ceiling_height', kind = 'hist', bins = 30, range = (2,10), grid=True, figsize = (5,3))
data['ceiling_height'].describe()
# Out:
# count              14,477.00
# mean                    2.74
# std                     0.87
# min                     1.00
# 25%                     2.51
# 50%                     2.65
# 75%                     2.80
# max                   100.00
# Name: ceiling_height, dtype: float64

# %%
data.boxplot('ceiling_height', vert=False)
# Out:
# <AxesSubplot:>

# %%
data_1= data.loc[(data['ceiling_height']< 4) & (data['ceiling_height']>2)]
data_1.boxplot('ceiling_height', vert=False)
# Out:
# <AxesSubplot:>

# %%
print(((data['ceiling_height'].count()-data_1['ceiling_height'].count())/data['ceiling_height'].count()*100))
# Out:
# 0.7321958969399738

# %%
data['ceiling_height'] = data_1['ceiling_height']
# Out:
# /tmp/ipykernel_48/234347409.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ceiling_height'] = data_1['ceiling_height']

# %% [markdown]
# боксплот показал, что выбивающимися значениями считаются потолки высотой более 3.1м и менее 2м , но поскольку вы написали выше в замечании, что в сталинках и новостройках бывают потолки 4м, такое значение и поставим, остальные значения уберем, они явно являются выбросами и нереальными значениями. Таких значений менее 1%, поэтому мы вполне можем от них избавиться

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %%
#изучим жилую площадь
data.plot(y = 'living_area', kind = 'hist', bins = 100, grid=True, figsize = (5,3), range = (0,400))
data['living_area'].describe()
# Out:
# count              23,547.00
# mean                   34.47
# std                    21.61
# min                     2.00
# 25%                    18.60
# 50%                    30.00
# 75%                    42.30
# max                   409.70
# Name: living_area, dtype: float64

# %%
data.boxplot('living_area', vert=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# из гистограммы и боксплота видно, медиана проходи через значение 30 кв.м, квартиры с жилой площадью более 74 кв.м считаются выбросами, но на парктике, мы не может утвержадть, что это нереальные значения, также бокс плот не посчитал выбросами квартиры с жилой площадью 2кв. м;

# %%
data_1= data.loc[data['living_area']< 74]
data_1.boxplot('living_area', vert=False)
# Out:
# <AxesSubplot:>

# %%
print(((data['living_area'].count()-data_1['living_area'].count())/data['living_area'].count()*100))
# Out:
# 3.7881683441627385

# %%
data= data.loc[data['living_area']> 8]

# %% [markdown]
# Из гистограммы размаха видно, что есть совсем небольшое количество выпадов, из них не все являются нереальными значениями, квартиры c жилой площадью от 75 кв.м не являются нереальными. Квартир с жилой площадью более 74 кв.м в датасете 3.8%; природа этих выбросов нам неизвестна, их оставим как есть, а уберем квартиры с жилой площадью менее 8кв.м

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %%
#изучим площадь кухни 
data.plot(y = 'kitchen_area', kind = 'hist', bins = 100, grid=True, figsize = (5,3), range = (0,120))
data['kitchen_area'].describe()
# Out:
# count              21,324.00
# mean                   10.56
# std                     5.90
# min                     1.30
# 25%                     7.00
# 50%                     9.10
# 75%                    12.00
# max                   112.00
# Name: kitchen_area, dtype: float64

# %%
data.boxplot('kitchen_area', vert=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# из гистограммы и боксплота видно, медиана проходит через значение 9 кв.м, квартиры с площадью кухни более 19 кв.м считаются выбросами, максимально значение площади кухни равно 112 кв.м мы не можем утверждать, что это нереальные значения, и оставим их, зато боксплот не посчитал выбросами кухни размером менее 3 кв. м. в реальности это невозможно, поэтому такие значения мы исключим.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %%
data= data.loc[data['kitchen_area']> 3]

# %%
#изучим типы этажей квартиры 
data.value_counts('floor_category').plot(y='number', kind='bar', legend=False)
data['floor_category'].describe()
# Out:
# count      21306
# unique         3
# top       другой
# freq       15676
# Name: floor_category, dtype: object

# %% [markdown]
# из диаграммы видно, больше всего квартир расположены на не первых и не последних этажах, меньше всего квартир расположены на первом этаже.

# %%
#изучим общее количество этажей в доме
data.plot(y = 'floors_total', kind = 'hist', bins = 100, grid=True, figsize = (5,3))
data['floors_total'].describe()
# Out:
# count              21,306.00
# mean                   10.59
# std                     6.53
# min                     1.00
# 25%                     5.00
# 50%                     9.00
# 75%                    15.00
# max                    60.00
# Name: floors_total, dtype: float64

# %% [markdown]
# диаграмма показывает, что большинство квартир располодена в домах с этажностью от 1 до 27.

# %%
data.boxplot('floors_total', vert=False)
# Out:
# <AxesSubplot:>

# %%
data_1= data.loc[data['floors_total']< 36]
data_1.boxplot('floors_total', vert=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Из боксплота видно, что количество этажей в доме, в котором расположена квартира считается выбросом, начиная от 28 этажей, в реальности значения перестают быть реальными после значения 36, поэтому все значения больше этого мы устраним.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %%
data['floors_total'] = data_1['floors_total']
# Out:
# /tmp/ipykernel_48/2387061303.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['floors_total'] = data_1['floors_total']

# %%
#изучим расстояние до центра города в метрах
data.plot(y = 'cityCenters_nearest', kind = 'hist', bins = 100, grid=True, figsize = (5,3), range = (0,70000))
data['cityCenters_nearest'].describe()
# Out:
# count              16,524.00
# mean               14,228.24
# std                 8,654.30
# min                   181.00
# 25%                 9,289.75
# 50%                13,100.00
# 75%                16,268.00
# max                65,968.00
# Name: cityCenters_nearest, dtype: float64

# %% [markdown]
# на гистогрмме видно, что большая часть квартир удалены от центра на расстояние от 0 до 18 тыс. м;

# %%
data.boxplot('cityCenters_nearest', vert=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Боксплот посчитал расстояние от центра более чем 26 тыс. м выбросами, но эти значения абсолютно реальны, поэтому оставим этот параметр без изменения.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %%
data.plot(y = 'parks_nearest', kind = 'hist', bins = 100, grid=True, figsize = (5,3), range = (0,3200))
data['parks_nearest'].describe()
# Out:
# count               7,354.00
# mean                  488.27
# std                   339.24
# min                     1.00
# 25%                   287.00
# 50%                   452.00
# 75%                   610.75
# max                 3,190.00
# Name: parks_nearest, dtype: float64

# %% [markdown]
# гистограмма показывает что большая часть квартир удалена от парков не более, чем на 1 км;

# %%
data.boxplot('parks_nearest', vert=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# боксплот показывает, что медиана проходит через значение 452м, расстояние до ближайшего парка более 1.1 км является выбросом, в реальности это не так. максимально значение 3км 200м тоже возможно, поэтому столбец с этими данными оставим без изменения.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <s><b>🤔 Рекомендация:</b> Эти значения нужно было исследовать и отфильтровать ранее, комментарий об этом я оставила выше</s>
# </div>

# %%
#диаграмма размаха
plt.boxplot(data[data['days_exposition']!=0]['days_exposition'])
plt.ylim(1,1000)

data.plot(y = 'days_exposition', kind = 'hist', bins = 30, grid = True, range = (1,1600))
data.plot(y = 'days_exposition', kind = 'hist', bins = 100, grid = True, range = (1,200))

#среднее значение, медиана и межквартильный размах
data[data['days_exposition']!=0]['days_exposition'].describe()
#data[data['days_exposition']!=0]['days_exposition'].value_counts()
# Out:
# count              18,338.00
# mean                  185.49
# std                   222.54
# min                     1.00
# 25%                    45.00
# 50%                   102.00
# 75%                   239.00
# max                 1,580.00
# Name: days_exposition, dtype: float64

# %% [markdown]
# Вывод: судя по гистограмме - мы имеем распределение Пуассона. Среднее значение - 180 дней, а медиана - 95 дней.
# Сделав гистограмму со значениями от 0 до 200 с кол-вом корзин 100, обнаружили выбивающиеся значения и методом
# value_counts убедились в этом - у нас аномалии на 45, 60, 7, 30, 90 днях - это наиболее популярное количество
# дней до снятия объявления.
# правила размещения объявлений в Яндекс Недвижимость, оказалось что именно после этих сроков объявление считается
# неактуальным и снимается автоматически.
# Наверное, нам нужно убрать эти значения из выборки, но нужно подумать есть ли еще критерии для снятия таких объявлений,
# ведь часть из таких квартир могла и правда продаться в этот срок.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно! Часть объявлений снимаются автоматически после определенного срока и их по каким-то причинам не продляют
# </div>

# %%
data[data['days_exposition']==45]
# Out:
#        total_images           last_price           total_area  \
# 78                9         4,350,000.00                37.00
# 89                9         2,500,000.00                63.00
# 110               6         3,850,000.00                72.30
# 153              12         4,350,000.00                55.00
# 158              15         3,100,000.00                47.30
# ...             ...                  ...                  ...
# 23390             8         2,156,000.00                36.00
# 23454             2         3,250,000.00                45.90
# 23482            19         3,600,000.00                39.70
# 23537             9         3,600,000.00                45.00
# 23695            14         3,100,000.00                59.00
#
#       first_day_exposition  rooms       ceiling_height         floors_total  \
# 78              2018-02-22      1                  NaN                19.00
# ...

# %% [markdown]
# Вывод: никаких общих особенностей в обьявлениях, снятых через 45 дней не выявлено, потому будем убирать эти данные из наших расчетов, как и данные с 60, 90, 30 и 7 дней в столбце days_exposition, так как это аномалии.
#
# До того, как мы очистим наши данные от аномалий, нам нужно дать ответ на вопрос, какое количество дней считать нормальным, а какое выбросом на текущий момент до очистки данных. Исходя из метода describe, межквартильный размах - от 45 до 232 дней, исходя же из метода boxplot - диаграмма размаха у нас от минимального значения до примерно 500 дней. Значит необоснованно быстрых значений у нас нет, а необоснованно долгие - от 500 дней и выше. Значит нормальные значения у нас лежат от 1 до 500.
#
# На текущий момент мы уже знаем, что эти данные неправильные, но они нам нужны, чтобы сравнить с данными, очищенными от аномалий далее.
#
# Считаю важным уточнить у сотрудников насчет выбивающихся значений по датам снятия объявлений, чтобы убедиться в том, какие данные необходимо исключить из выборки.

# %% [markdown]
# <div class="alert alert-warning">
# <b>🤔 Рекомендация:</b> Квартиры могут продаваться как за 1 день, так и годами, в этом столбце нет нереальных значений, их вчсе можно объяснить, а значит и удалять их не нужно
# </div>

# %%
#отфильтруем данные от аномалий и запишем их в новый датафрейм good_data
good_data = data.query('days_exposition != 45 and days_exposition != 30 and days_exposition != 60 and days_exposition != 90 and days_exposition != 7 and days_exposition != 0')

#диаграмма размаха
plt.boxplot(good_data['days_exposition'])
plt.ylim(1,1000)

#гистограммы
good_data.plot(y = 'days_exposition', kind = 'hist', bins = 30, grid = True, range = (1,1600))
good_data.plot(y = 'days_exposition', kind = 'hist', bins = 100, grid = True, range = (1,200))

#среднее значение, медиана и межквартильный размах
#good_data['days_exposition'].value_counts()
good_data['days_exposition'].describe()
# Out:
# count              16,889.00
# mean                  197.49
# std                   227.84
# min                     1.00
# 25%                    46.00
# 50%                   115.00
# 75%                   261.00
# max                 1,580.00
# Name: days_exposition, dtype: float64

# %% [markdown]
# Вывод: ожидаемо, в очищенных данных с аномалиями в значениях меньших медианы получаем бОльшие значения медианы и среднего значения - 114 и 195 соответственно, вместо 95 и 180. Аналогично, теперь нормальные значения располагаются от 1 до 600 дней вместо от 1 до 500 дней.

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> С ячейки ниже начинется другой пункт нашего исследования, стоит его выделить. Здесь уже нужно смотреть на корреляцию числовых признаков, визуализировать зависимости, например, применив  sns.pairplot. Здесь нужно исследовать не стоимость квадратного метра, а стоимость квартиры</s>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>🎓выделила и исправила

# %% [markdown]
# ИЗУЧИМ ЗАВИСИМОСТЬ ЦЕНЫ КВАРТИРЫ ОТ ПАРАМЕТРОВ

# %%
#Изучим зависимость цены квадратного метра от общей площади квартиры
pivot_table_total_area = data.pivot_table(index = 'total_area', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_total_area.columns = ['mean', 'count', 'median']
pivot_table_total_area.plot(y = 'median', style = 'o')

pivot_table_total_area.sort_values('median', ascending = False)

data['total_area'].corr(data['last_price'])
# Out:
# 0.6974305451412149

# %% [markdown]
# видим, довольно сильную зависимость согласно корреляции Пирсона практически  - 0.7; То есть, чем больше площадь тем выше стоимость

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %%
#Изучим зависимость цены кквартиры от жилой площади квартиры
pivot_table_living_area = data.pivot_table(index = 'living_area', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_living_area.columns = ['mean', 'count', 'median']
pivot_table_living_area.plot(y = 'median', style = 'o')

pivot_table_living_area.sort_values('median', ascending = False)

data['living_area'].corr(data['last_price'])
# Out:
# 0.5968617037568456

# %% [markdown]
# видим, что зависимость tcnm - согласно корреляции Пирсона gjxnb - 0.6! То есть, чем больше площадь тем выше стоимость квартиры

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %%
#Изучим зависимость цены квартиры от площади кухни
pivot_table_kitchen_area = data.pivot_table(index = 'kitchen_area', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_kitchen_area.columns = ['mean', 'count', 'median']
pivot_table_kitchen_area.plot(y = 'median', style = 'o')

pivot_table_kitchen_area.sort_values('median', ascending = False)

data['kitchen_area'].corr(data['last_price'])
# Out:
# 0.5212246784302732

# %% [markdown]
# видим, что есть зависимость  - согласно корреляции Пирсона - 0.5! То есть, чем больше площадь кухни тем выше стоимость квартиры

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %%
#Изучим зависимость цены квартиры от числа комнат
pivot_table_rooms = data.pivot_table(index = 'rooms', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_rooms.columns = ['mean', 'count', 'median']
pivot_table_rooms.query('count > 50').plot(y = 'median')

pivot_table_rooms.query('count > 50').sort_values('median', ascending = False)

data['rooms'].corr(data['last_price'])
# Out:
# 0.39094060021882726

# %% [markdown]
# есть зависимость и мы видим, что чем больше комнат в квартире тем выше её цена, так как больше площадь

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %%
#Изучим зависимость цены квартиры от этажа (первого или последнего)
pivot_table_floor_category = data.pivot_table(index = 'floor_category', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_floor_category.columns = ['mean', 'count', 'median']
pivot_table_floor_category.plot(y = 'median')
pivot_table_floor_category
# Out:
#                                mean  count               median
# floor_category
# другой                 6,711,532.32  15676         4,900,000.00
# первый                 4,851,984.85   2595         3,950,000.00
# последний              7,124,725.37   3035         4,350,000.00

# %% [markdown]
# Вывод: самыми дешевыми являются квартиры на первом этаже, последние этажи тоже сильно устпают по цене категории "другие", но продаются дороже первых, и самыми дорогими являются квартиры расположенные на категории этажей "другие", иными словами расположенные не на первом и прследнем этаже.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %%
#Изучим зависимость цены квартиры от даты размещения: месяца
pivot_table_month_exposition = data.pivot_table(index = 'month_exposition', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_month_exposition.columns = ['mean', 'count', 'median']
pivot_table_month_exposition.plot(y = 'median')

pivot_table_month_exposition.sort_values('median', ascending = False)
# Out:
#                                  mean  count               median
# month_exposition
# 12                       7,189,813.93   1371         4,850,000.00
# 4                        6,816,100.16   2177         4,833,675.00
# 2                        6,597,139.18   2340         4,750,000.00
# 9                        6,466,494.22   1848         4,750,000.00
# 1                        6,635,766.83   1285         4,700,000.00
# 3                        6,428,079.51   2317         4,700,000.00
# 11                       6,473,694.47   2182         4,700,000.00
# 7                        6,454,966.91   1500         4,680,000.00
# 8                        6,427,294.03   1580         4,680,000.00
# 10                       6,165,992.46   1961         4,600,000.00
# 5                        6,632,258.77   1145         4,550,000.00
# 6                        6,419,816.57   1600         4,494,500.00

# %% [markdown]
# самая высокая стоимость квартир в апреле и декабре! Самая низкая стоимость в мае и июне! На рынке недвижимости, как и во многих других сферах присутствует сезонность - в начале лета мы видим наименьший прайс на недвижимость. Наверное, это связано с отпусками, также мы видим просадку в октябре и стремительный рост к декабрю.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %%
#Изучим зависимость цены квартиры от даты размещения: дня недели.
pivot_table_weekday_exposition = data.pivot_table(index = 'weekday_exposition', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_weekday_exposition.columns = ['mean', 'count', 'median']
pivot_table_weekday_exposition.plot(y = 'median')

pivot_table_weekday_exposition.sort_values('median', ascending = False)
# Out:
#                                    mean  count               median
# weekday_exposition
# 1                          6,452,217.56   3784         4,800,000.00
# 2                          6,600,926.59   3577         4,750,000.00
# 0                          6,650,873.04   3293         4,700,000.00
# 3                          6,791,660.23   3882         4,700,000.00
# 4                          6,258,337.31   3591         4,600,000.00
# 5                          6,589,519.43   1699         4,600,000.00
# 6                          6,393,165.17   1480         4,595,000.00

# %% [markdown]
# видим, что чем ближе ко вторнику выставлены объявления тем в среднем выше стоимость, но незначительно! С пятницы по воскресенье стоимость самая низкая!
#
# Полагаю, что стоимость выставленной на продажу недвижимости зависит от общей активности людей, так как именно в рабочие дни мы видим более высокие цены.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %%
#Изучим зависимость цены квартиры от даты размещения: года.
pivot_table_year_exposition = data.pivot_table(index = 'year_exposition', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_year_exposition.columns = ['mean', 'count', 'median']
pivot_table_year_exposition.plot(y = 'median')

pivot_table_year_exposition.sort_values('median', ascending = False)
# Out:
#                                 mean  count               median
# year_exposition
# 2014                   11,962,473.59    128         7,640,000.00
# 2015                    8,291,803.49   1068         5,300,000.00
# 2019                    6,765,536.58   2663         5,099,000.00
# 2018                    6,073,380.25   7452         4,650,000.00
# 2016                    6,717,873.15   2536         4,550,000.00
# 2017                    6,532,457.47   7459         4,550,000.00

# %% [markdown]
# видим, что с 2014 до 2016 года цена падала, но далее начала в среднем увеличиваться, начиная с 2017 года . Мы не рассматриваем сегментацию рынка и по факту стоимость аналогичных квартир могла себя вести абсолютно иначе от года к году.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %%
locality_pivot_table = data.pivot_table(index = 'locality_name', values = 'price_per_square_meter', aggfunc=['count', 'mean'])
locality_pivot_table.columns = ['count', 'mean']
locality_pivot_table = locality_pivot_table.sort_values('count', ascending = False).head(10)
locality_pivot_table
# Out:
#                  count                 mean
# locality_name
# Санкт-Петербург  14285           114,172.80
# Мурино             478            85,529.14
# Шушары             397            78,413.27
# Кудрово            387            95,241.71
# Всеволожск         357            69,028.69
# Пушкин             337           103,198.15
# Колпино            322            75,225.87
# Гатчина            294            68,692.48
# Парголово          289            90,690.92
# Выборг             201            58,365.02

# %% [markdown]
# самая высокая стоимость жилья из 10 населённых пунктов с самым большим количеством объявлений в Санкт-Петербурге, тогда как самая низкая стоимость в Выборге.

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> Здесь нужно добавить визуализации (гистограмму, боксплоты по населенным пунктам)</s>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>🎓  в задании проекта нет задачи сделать визуализацию, необходимо вывести только сводную таблицу, следовала четко заданию

# %%
data['Center_nearest_in_km'] = data['Center_nearest_in_km'].fillna(999999)
data['Center_nearest_in_km'] = data['Center_nearest_in_km'].astype('int')
pivot_table_km = data.query('locality_name == "Санкт-Петербург" and Center_nearest_in_km !=999999').pivot_table(index = 'Center_nearest_in_km', values = 'price_per_square_meter', aggfunc = 'mean')
pivot_table_km.plot()
pivot_table_km
# Out:
#                       price_per_square_meter
# Center_nearest_in_km
# 0                                 252,385.50
# 1                                 170,672.54
# 2                                 160,075.58
# 3                                 120,689.86
# 4                                 129,475.42
# 5                                 138,994.47
# 6                                 148,282.21
# 7                                 156,838.98
# 8                                 126,068.59
# 9                                 112,850.26
# 10                                111,907.52
# 11                                108,124.22
# 12                                107,337.46
# 13                                107,597.34
# 14                                103,689.13
# 15                                104,255.81
# 16                                100,306.24
# 17                                 96,754.53
# 18                                 96,774.46
# ...

# %% [markdown]
# судя по графику центром считать будем радиус в 7 километров, что для Санкт етербурга является нормалтной географической величиной.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# Мы обработали полученный архив данных - обработали пропущенные значения там, где это необходимо, мы заменили на медианные значения , заменили типы данных на необходимые для удобной работы. Посчитали и добавили в таблицу цену квадратного метра жилья, вывели из даты дни недели, месяцы и года размещения объявлений, добавили категории по этажам квартир. Изучили следующие параметры на наличие выбивающихся значений - общая площадь;
# жилая площадь;
# площадь кухни;
# цена объекта;
# количество комнат;
# высота потолков;
# тип этажа квартиры («первый», «последний», «другой»);
# общее количество этажей в доме;
# расстояние до центра города в метрах;
# расстояние до ближайшего парка.
# Были определены аномалии в данных параметрах. Изучая время продажи квартир мы выявили, что большое количество объявлений было автоматически снято с Яндекс Недвижимость и дату из снятия нельзя считать датой продажи квартиры, поэтому, изучая средние сроки продажи квартир - данные значения не учитывались. Мы выявили при помощи диаграммы размаха, что нормальные значения продажи квартир варьируются от 1 до 600 дней. Мы выявили, что на стоимость  квартиры больше всего влияют количество комнат, этаж квартиры(самые дорогие квартиры расположенные не на первом и не на последнем этаже, квартиры на первых этажах- самые дешевые) и близость к центру, также довольно значительно на стоимость квартиры влияют общая площадь(коэффициент корреляции Пирсона 0,69) и жилая площадь (коэффициент корреляции Пирсона 0,59).
# Нужно учитывать, что в 2016-2017 годах стоимость квартир в среднем по рынку была ниже на 10-20 %, тогда как в центре Санкт-Петербурга данной зависимости от года не обнаружено. В данном случае имело место постоянное удорожание стоимости, начиная с 2015 года по текущий момент. Судя, по резкости изменения цен в зависимости от удаления от центра СПБ, мы выявили центр города в радиусе 7 километров.
#
# Также важно учитывать, что, рассматривая среднюю стоимость квартир в 2014-2019 годах, мы не делали сегментацию рынка, а лишь смотрели средние показатели по рынку в целом. С 2014 по 2016 год цены на недвижимость падали, с 2016 по 2017 цены находились практически на одном уровне, с минимальным ростом, с 2017 года рынок стал стремительно расти.Т.е. возможно, что цены на аналогичные квартиры в разных годах вели себя абсолютно по-разному. Т.е. например в то время, когда средняя стоимость метра по рынку в 2016-2017 годах была наиболее низкой, какие-то аналогичные прошлым годам квартиры могли и не падать в цене, а наоборот дорожать! Именно об этом нам и говорят данные, полученные при изучении единственного сегмента квартир - находящихся в радиусе 7 км в центре СПБ.

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> В итоговои выводе нужно более конкретно и с цифрами описать что получили в исследовании, дать какие-то рекомендации заказчику. Анализ по годам тоже хорошо было бы добавить в работу</s>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>🎓 исправила

# %% [markdown]
# <div class="alert alert-warning">
# <b>Итоговый комментарий по первой итерации проекта</b> У тебя многое хоргшо получилось и есть интересные идеи, но проекту не хватает структурности, не все данные исследованы. Приведение типов данных к нужным проводится отдельно в начале работы после того, как обнарежено несоответствие типов данных. Обязательно нужно смотреть на датасет после изменений, правильно ли получились новые признаки, правильно ли произошла замена и т.п. Поле каждой визуализации должен быть вывод - что мы там увидели, что с тим можно сделать.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Получился отличный проект! Спасибо большое тебе за такую качественную работу. Мне было приятно проверять проект и делиться обратной связью. Такой вывод даст достаточно информации заказчику иследования, и если ему будут нужны подробности, то он их легко найдет в самой работе, ты подробно комментировала все свои действия и писала промежуточные выводы, такое будет понятно даже тем, кто плохо разбирается в коде! У тебя хорошо получилось группировать данные и смотреть не только на весь датасет в целом, но и на отдельные "кусочки", часто такие зависимости не являются конечной целью исследования, но играют важную роль и позволяют лучше понимать данные и принимать решения об их обработке или удалении.
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
